# %%
from IPython.display import display, Image
from agents.supervisor import Supervisor

# Create supervisor instance
supervisor = Supervisor()

# Display the graph
if supervisor.graph:
    display(Image(supervisor.graph.get_graph().draw_mermaid_png()))
